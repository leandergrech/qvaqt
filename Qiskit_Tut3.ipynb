# %%
from qiskit import *

# %%
c = QuantumCircuit(3, 3)
c.x(1)
c.h(range(3))
c.cx(0, 1)
c.measure(range(3), range(3))

print(c)
c.draw()
# Out:
#      ┌───┐          ┌─┐
# q_0: ┤ H ├───────■──┤M├───
#      ├───┤┌───┐┌─┴─┐└╥┘┌─┐
# q_1: ┤ X ├┤ H ├┤ X ├─╫─┤M├
#      ├───┤└┬─┬┘└───┘ ║ └╥┘
# q_2: ┤ H ├─┤M├───────╫──╫─
#      └───┘ └╥┘       ║  ║
# c: 3/═══════╩════════╩══╩═
#             2        0  1
#      ┌───┐          ┌─┐
# q_0: ┤ H ├───────■──┤M├───
#      ├───┤┌───┐┌─┴─┐└╥┘┌─┐
# q_1: ┤ X ├┤ H ├┤ X ├─╫─┤M├
#      ├───┤└┬─┬┘└───┘ ║ └╥┘
# q_2: ┤ H ├─┤M├───────╫──╫─
#      └───┘ └╥┘       ║  ║
# c: 3/═══════╩════════╩══╩═
#             2        0  1

# %%
c.draw(output='mpl', scale=2.0)

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# %qiskit_copyright
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td><code>qiskit-terra</code></td><td>0.22.3</td></tr><tr><td><code>qiskit-aer</code></td><td>0.11.2</td></tr><tr><td><code>qiskit-ibmq-provider</code></td><td>0.19.2</td></tr><tr><td><code>qiskit</code></td><td>0.39.4</td></tr><tr><th>System information</th></tr><tr><td>Python version</td><td>3.10.8</td></tr><tr><td>Python compiler</td><td>GCC 11.2.0</td></tr><tr><td>Python build</td><td>main, Nov 24 2022 14:13:03</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>2</td></tr><tr><td>Memory (Gb)</td><td>7.6745452880859375</td></tr><tr><td colspan='2'>Mon Jan 16 17:06:59 2023 CET</td></tr></table>
# ...
