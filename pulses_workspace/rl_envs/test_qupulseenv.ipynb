# %%
import numpy as np
from qu_pulse_env import QuPulseEnv
from qutip_qip.circuit import QubitCircuit

# %%
qc = QubitCircuit(N=1)
qc.add_gate('X', targets=0)
env = QuPulseEnv(qc=qc)
env.action_eps = 0.1
env.rew_scale = 1.0
# Out:
# /home/leander/miniconda3/envs/qvaqt/lib/python3.10/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
max_steps = 10
o = env.reset()
d = False

obses = []
acts = []
rews = []

# %%
step = 0
while not d and step < max_steps:
    a = [0, 1, 1]

    otp1, r, d, info = env.step(a)

    acts.append(a)
    obses.append(otp1)
    rews.append(r)

    o = otp1
    step += 1

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3)
ax = axs[0]
ax.plot(obses)
ax = axs[1]
ax.plot(acts)
ax = axs[2]
ax.plot(rews)
